# %%
import numpy as np 
import matplotlib.pyplot as plt
import random

from cffi import model
from sklearn.pipeline import Pipeline

X = 2 * np.random.rand(100,1)
Y = 4 + 3 * X + np.random.randn(100,1)
plt.scatter(X,Y, color='blue')
plt.show()

# %%
X_b = np.c_[np.ones((100,1)), X] #Dodaje x0 = 1 dla każdej próbki 
theta_best = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(Y) 
 #Służy on do pomiaru, jak dobrze (lub źle) model jest dopasowany do danych uczących, poprzez mierzenie odległości między przewidywaniami modelu a rzeczywistymi etykietami

# %%
X_new = np.array([[0], [2]])
X_new_b = np.c_[np.ones((2,1)), X_new]
y_predict = X_new_b.dot(theta_best)
y_predict
# Out:
# array([[4.14617348],
#        [9.99375376]])

# %%
plt.plot(X_new, y_predict, "r-")
plt.plot(X,Y, "b.")
plt.axis([0,2,0,15])
plt.show()

# %%
from sklearn.linear_model import LinearRegression 
lin_reg = LinearRegression()
lin_reg.fit(X,Y)
lin_reg.intercept_, lin_reg.coef_ #odczytuje i zwraca wyuczone paarametry (wagi) modelu
#lin_reg.intercept_ - przewidywana wartość zmiennej wyjściowej y, gdy wszystkie x są równe 0 
#lin_reg.coef_ - współczynnik kierunkowy
# Out:
# (array([4.14617348]), array([[2.92379014]]))

# %%
lin_reg.predict(X_new)
# Out:
# array([[4.14617348],
#        [9.99375376]])

# %% [markdown]
# Gradient prosty

# %%
#określanie kroku gradientu prostego 
eta = 0.1 
n_iterations = 1000 #liczba iteracji 
m = 100 #liczba przykładów uczących w zbiorze 
theta = np.random.randn(2,1) #Losowa inicjacja 
for iteration in range(n_iterations):
    gradients = 2/m * X_b.T.dot(X_b.dot(theta) - Y)
    theta = theta - eta * gradients
theta
# Out:
# array([[4.14617348],
#        [2.92379014]])

# %%
n_epochs = 50
t0, t1, = 5,50

def learning_shedule(t):
    return t0 / (t+t1)

theta = np.random.rand(2,1) #wektor parametrów wag 
for epoch in range (n_epochs):
    for i in range(m):
        random_index = np.random.randint(m)
        xi = X_b[random_index:random_index+1]
        yi = Y[random_index:random_index+1]
        gradients = 2 * xi.T.dot(xi.dot(theta) - yi)
        eta = learning_shedule(epoch * m + i)
        theta = theta - eta * gradients
theta
# Out:
# array([[4.14525052],
#        [2.87311164]])

# %%
from sklearn.linear_model import SGDRegressor
sgd_reg = SGDRegressor(max_iter=1000, tol=1e-3, penalty=None, eta0=0.1)
sgd_reg.fit(X,Y.ravel())
# Out:
# SGDRegressor(eta0=0.1, penalty=None)

# %%
sgd_reg.intercept_, sgd_reg.coef_
# Out:
# (array([4.11089567]), array([2.8755467]))

# %% [markdown]
# Regresja wielomainowa

# %%
m = 100
X = 6 * np.random.rand(m,1) -3
y = 0.5 * X**2 + X + 2 + np.random.rand(m,1)
plt.scatter(X,y, color='blue')
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures, StandardScaler

poly_features = PolynomialFeatures(degree=2, include_bias=False)
X_poly = poly_features.fit_transform(X)
X[0]
# Out:
# array([2.77294962])

# %%
X_poly[0]
# Out:
# array([2.77294962, 7.68924959])

# %%
lin_reg = LinearRegression()
lin_reg.fit(X_poly,Y)
lin_reg.intercept_, lin_reg.coef_
# Out:
# (array([6.75544091]), array([[-0.04613548,  0.11506401]]))

# %%
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
def plot_learning_curve(estimator, X, y):
    X_train,X_val,y_train,y_val = train_test_split(X, y, test_size=0.2)
    train_errors, val_errors = [],[]
    for m in range(1,len(X_train)):
        lin_reg.fit(X_train[:m], y_train[:m])
        y_train_pred = lin_reg.predict(X_train[:m])
        y_val_pred = lin_reg.predict(X_val)
        train_errors.append(mean_squared_error(y_train[:m], y_train_pred))
        val_errors.append(mean_squared_error(y_val, y_val_pred))

# %%
#przeprowadzanie regresji grzbietowej za pomocą jawnego wzoru 
from sklearn.linear_model import Ridge 
ridge_reg = Ridge(alpha=1, solver='cholesky')
ridge_reg.fit(X,y)
ridge_reg.predict([[1.5]])
# Out:
# array([5.9084995])

# %%
#metoda lasso 
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha=0.1)
lasso_reg.fit(X,y)
lasso_reg.predict([[1.5]])
# Out:
# array([5.8765024])

# %%
#metoda elastycznej siatki 
from sklearn.linear_model import ElasticNet
elastic_net = ElasticNet(alpha=0.1, l1_ratio=0.5)
elastic_net.fit(X,y)
elastic_net.predict([[1.5]])
# Out:
# array([5.87389355])

# %%
from sklearn import datasets
iris = datasets.load_iris()
list(iris.keys())
# Out:
# ['data',
#  'target',
#  'frame',
#  'target_names',
#  'DESCR',
#  'feature_names',
#  'filename',
#  'data_module']

# %%
import numpy as np
X = iris["data"][:,3:]
y = (iris["target"] ==2).astype(int)

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression()
log_reg.fit(X,y)
# Out:
# LogisticRegression()
